# %%
import pandas as pd
data = pd.read_csv("datasets\marks.csv")
print(data.head())
# Out:
#   Name  Age  StudyHours  Marks
# 0    A   18           2     50
# 1    B   19           5     80
# 2    C   18           3     60
# 3    D   20           6     90
# 4    E   21           4     70

# %%
import numpy as np

print(data["StudyHours"].mean())
print(data["StudyHours"].median())
print(data["StudyHours"].std())
# Out:
# 4.0
# 4.0
# 1.5811388300841898

# %%
print(data.shape)
# Out:
# (5, 4)

# %%
print(data.dtypes)
# Out:
# Name            str
# Age           int64
# StudyHours    int64
# Marks         int64
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# Name          0
# Age           0
# StudyHours    0
# Marks         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(data["StudyHours"], data["Marks"])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.show()

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\jayshri\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.4.1)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 3.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 3.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 3.2 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.1 MB 2.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 2.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 2.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.0 MB/s eta 0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.6 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.0/36.6 MB 1.8 MB/s eta 0:00:20
#    - -------------------------------------- 1.6/36.6 MB 1.9 MB/s eta 0:00:19
#    -- ------------------------------------- 1.8/36.6 MB 1.9 MB/s eta 0:00:18
#    -- ------------------------------------- 2.4/36.6 MB 2.0 MB/s eta 0:00:18
#    --- ------------------------------------ 2.9/36.6 MB 2.1 MB/s eta 0:00:17
#    --- ------------------------------------ 3.4/36.6 MB 2.1 MB/s eta 0:00:17
#    ---- ----------------------------------- 3.9/36.6 MB 2.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.2/36.6 MB 2.1 MB/s eta 0:00:16
#    ----- ---------------------------------- 4.7/36.6 MB 2.1 MB/s eta 0:00:16
#    ----- ---------------------------------- 5.2/36.6 MB 2.1 MB/s eta 0:00:15
#    ------ --------------------------------- 5.8/36.6 MB 2.1 MB/s eta 0:00:15
#    ------ --------------------------------- 6.0/36.6 MB 2.1 MB/s eta 0:00:15
#    ------ --------------------------------- 6.3/36.6 MB 2.1 MB/s eta 0:00:15
#    ------- -------------------------------- 6.6/36.6 MB 2.0 MB/s eta 0:00:15
#    ------- -------------------------------- 6.8/36.6 MB 2.0 MB/s eta 0:00:15
#    -------- ------------------------------- 7.3/36.6 MB 1.9 MB/s eta 0:00:16
#    -------- ------------------------------- 7.9/36.6 MB 2.0 MB/s eta 0:00:15
#    -------- ------------------------------- 8.1/36.6 MB 1.9 MB/s eta 0:00:15
#    --------- ------------------------------ 8.7/36.6 MB 2.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 9.2/36.6 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 9.7/36.6 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.0/36.6 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.0/36.6 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 10.5/36.6 MB 1.9 MB/s eta 0:00:14
#    ----------- ---------------------------- 10.7/36.6 MB 1.9 MB/s eta 0:00:14
#    ------------ --------------------------- 11.0/36.6 MB 1.9 MB/s eta 0:00:14
#    ------------ --------------------------- 11.5/36.6 MB 1.9 MB/s eta 0:00:14
#    ------------ --------------------------- 11.8/36.6 MB 1.9 MB/s eta 0:00:14
#    ------------- -------------------------- 12.3/36.6 MB 1.9 MB/s eta 0:00:13
#    ------------- -------------------------- 12.6/36.6 MB 1.9 MB/s eta 0:00:13
#    -------------- ------------------------- 13.1/36.6 MB 1.9 MB/s eta 0:00:13
#    -------------- ------------------------- 13.4/36.6 MB 1.9 MB/s eta 0:00:13
#    --------------- ------------------------ 13.9/36.6 MB 1.9 MB/s eta 0:00:13
#    --------------- ------------------------ 14.2/36.6 MB 1.9 MB/s eta 0:00:13
#    --------------- ------------------------ 14.4/36.6 MB 1.9 MB/s eta 0:00:12
#    ---------------- ----------------------- 14.7/36.6 MB 1.8 MB/s eta 0:00:12
#    ---------------- ----------------------- 15.2/36.6 MB 1.8 MB/s eta 0:00:12
#    ----------------- ---------------------- 15.7/36.6 MB 1.8 MB/s eta 0:00:12
#    ----------------- ---------------------- 16.3/36.6 MB 1.9 MB/s eta 0:00:11
#    ------------------ --------------------- 16.8/36.6 MB 1.9 MB/s eta 0:00:11
#    ------------------ --------------------- 17.0/36.6 MB 1.9 MB/s eta 0:00:11
#    ------------------- -------------------- 17.6/36.6 MB 1.9 MB/s eta 0:00:11
#    ------------------- -------------------- 18.1/36.6 MB 1.9 MB/s eta 0:00:10
#    -------------------- ------------------- 18.6/36.6 MB 1.9 MB/s eta 0:00:10
#    -------------------- ------------------- 18.9/36.6 MB 1.9 MB/s eta 0:00:10
#    --------------------- ------------------ 19.4/36.6 MB 1.9 MB/s eta 0:00:10
#    --------------------- ------------------ 19.9/36.6 MB 1.9 MB/s eta 0:00:09
#    ---------------------- ----------------- 20.4/36.6 MB 1.9 MB/s eta 0:00:09
#    ---------------------- ----------------- 21.0/36.6 MB 1.9 MB/s eta 0:00:09
#    ----------------------- ---------------- 21.5/36.6 MB 1.9 MB/s eta 0:00:08
#    ------------------------ --------------- 22.0/36.6 MB 1.9 MB/s eta 0:00:08
#    ------------------------ --------------- 22.5/36.6 MB 2.0 MB/s eta 0:00:08
#    ------------------------- -------------- 23.1/36.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 23.9/36.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 24.4/36.6 MB 2.0 MB/s eta 0:00:07
#    --------------------------- ------------ 24.9/36.6 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 25.4/36.6 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.0/36.6 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.5/36.6 MB 2.0 MB/s eta 0:00:05
#    ----------------------------- ---------- 27.0/36.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 27.8/36.6 MB 2.1 MB/s eta 0:00:05
#    ------------------------------ --------- 28.3/36.6 MB 2.1 MB/s eta 0:00:04
#    ------------------------------- -------- 28.8/36.6 MB 2.1 MB/s eta 0:00:04
#    -------------------------------- ------- 29.4/36.6 MB 2.1 MB/s eta 0:00:04
#    -------------------------------- ------- 29.6/36.6 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 30.4/36.6 MB 2.1 MB/s eta 0:00:03
#    --------------------------------- ------ 30.9/36.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.5/36.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.7/36.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.2/36.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.8/36.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 33.0/36.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 33.6/36.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------- -- 34.1/36.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------- -- 34.3/36.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------------------- - 34.9/36.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 2.1 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

X = data[["StudyHours"]]
y = data["Marks"]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

model = LinearRegression()
model.fit(X_train,y_train)

pred = model.predict(X_test)
