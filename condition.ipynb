# %%
a = input("Enter the first number: ")
b = input("Enter the second number: ")
c = input("Enter the third number: ")

if(a>b):
    print (a, "is greater")
    if(a>b):
        print (a, "is greater ")

if(b>a):
    print (b, "is greater")
    if(b>c):
        print (b, "is greter")
        
else:
    print (c, "is greater")

# %%
a = 20
b = 30
c = 40
print (max(a, max(b,c)))
# Out:
# 40
