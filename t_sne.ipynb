# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %%
df = pd.read_csv("datasets\customer_data.csv")

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#     customer_id        age  gender  annual_income  spending_score  \
# 0             1  22.000000  Female          32000              81
# 1             2  35.000000    Male          54000              43
# 2             3  28.000000  Female          61000              67
# 3             4  41.000000    Male          78000              25
# 4             5  19.000000  Female          25000              89
# 5             6  33.000000    Male          47000              52
# 6             7  35.243243  Female          39000              74
# 7             8  48.000000    Male          92000              18
# 8             9  30.000000  Female          68000              61
# 9            10  35.243243    Male          36000              77
# 10           11  52.000000  Female         105000              22
# 11           12  37.000000    Male          59000              48
# 12           13  29.000000  Female          72000              69
# 13           14  35.243243    Male          84000              31
# 14           15  21.000000  Female          28000              92
# 15           16  34.000000    Male          51000              55
# 16           17  27.000000  Female          43000              63
# 17           18  39.000000    Male          76000              36
# 18           19  23.000000  Female          34000              85
# 19           20  50.000000    Male          98000              27
# 20           21  31.000000  Female          65000              58
# 21           22  42.000000    Male          87000              41
# 22           23  25.000000  Female          41000              71
# 23           24  46.000000    Male          93000              29
# 24           25  38.000000  Female          71000              60
# 25           26  20.000000    Male          30000              88
# 26           27  55.000000  Female         112000              19
# 27           28  32.000000    Male          56000              47
# 28           29  44.000000  Female          89000              33
# 29           30  27.000000    Male          45000              76
# 30           31  36.000000  Female          62000              57
# 31           32  49.000000    Male         101000              24
# 32           33  24.000000  Female          37000              83
# 33           34  40.000000    Male          81000              38
# 34           35  29.000000  Female          69000              66
# 35           36  53.000000    Male          97000              21
# 36           37  22.000000  Female          29000              90
# 37           38  43.000000    Male          86000              35
# 38           39  33.000000  Female          58000              54
# 39           40  47.000000    Male          94000              28
#
#     purchase_frequency  Last_purchase_days              city
# 0                   14                   7          New York
# 1                    9                  18       Los Angeles
# 2                   11                  12           Chicago
# 3                    6                  45           Houston
# 4                   18                   3           Phoenix
# 5                   10                  21      Philadelphia
# 6                   13                   9       San Antonio
# 7                    4                  60         San Diego
# 8                   12                  15            Dallas
# 9                   15                   8          San Jose
# 10                   3                  72            Austin
# 11                   8                  24      Jacksonville
# 12                  12                  11        Fort Worth
# 13                   5                  39          Columbus
# 14                  20                   2         Charlotte
# 15                  10                  17     San Francisco
# 16                  11                  14      Indianapolis
# 17                   7                  28           Seattle
# 18                  16                   5            Denver
# 19                   4                  54        Washington
# 20                  10                  16            Boston
# 21                   6                  33           El Paso
# 22                  13                  10           Detroit
# 23                   4                  48         Nashville
# 24                  11                  13           Memphis
# 25                  19                   4          Portland
# 26                   2                  80         Las Vegas
# 27                   9                  22        Louisville
# 28                   5                  37         Baltimore
# 29                  14                   8         Milwaukee
# 30                  10                  19       Albuquerque
# 31                   3                  68            Tucson
# 32                  17                   6            Fresno
# 33                   6                  31        Sacramento
# 34                  12                  12       Kansas City
# 35                   4                  77           Atlanta
# 36                  18                   3             Miami
# 37                   5                  42  Colorado Springs
# 38                   9                  20           Raleigh
# 39                   4                  50             Omaha

# %%
df['gender']=df['gender'].map({'Male':0, 'Female':1})
df = pd.get_dummies(df, columns=['city'])

# %%
X = df.drop('customer_id', axis =1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
tsne = TSNE(
    n_components=2,
    perplexity=30,
    max_iter=1000,
    random_state=42
)

# %%
X_tsne = tsne.fit_transform(X_scaled)
plt.figure(figsize=(8,6))
plt.scatter(X_tsne[:,0],X_tsne[:,1])
plt.title("t-SNE Visualization (Customer Segmentation)")
plt.xlabel("Component 1")
# Out:
# Text(0.5, 0, 'Component 1')
