# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets\train_and_test2.csv')

print(df.head())
print(df.describe())
print(df.info())

mse = np.mean((y_pred - Y) **2)
print("Mean Squeared Error:", mse)

plt.scatter(X,y_pred)
plt.plot(df['History'], model.predict(X), color='red')
plt.xlabel('History')
plt.ylabel('Civics')
plt.title('Decision Tree Regression')
plt.show()
